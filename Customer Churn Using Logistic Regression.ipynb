# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\raghu\\Downloads\\customer_churn (1).csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# total charges is the ambiguity
data["TotalCharges"].value_counts()
# Out:
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
data.shape
# Out:
# (7043, 21)

# %%
data[data["TotalCharges"]==" "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
data["TotalCharges"]=pd.to_numeric(data["TotalCharges"],errors="coerce") #dealing with the ambiguity

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
data[data["customerID"]=="4472-LVYGI"]
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488  4472-LVYGI  Female              0     Yes        Yes       0
#
#     PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 488           No  No phone service             DSL            Yes  ...
#
#     DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 488              Yes         Yes         Yes              No  Two year
#
#     PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 488              Yes  Bank transfer (automatic)          52.55           NaN
#
#      Churn
# 488     No
#
# [1 rows x 21 columns]

# %%
#That is convertes as null value

# %%
data.describe(include="O").T
# Out:
#                  count unique               top  freq
# customerID        7043   7043        7590-VHVEG     1
# gender            7043      2              Male  3555
# Partner           7043      2                No  3641
# Dependents        7043      2                No  4933
# PhoneService      7043      2               Yes  6361
# MultipleLines     7043      3                No  3390
# InternetService   7043      3       Fiber optic  3096
# OnlineSecurity    7043      3                No  3498
# OnlineBackup      7043      3                No  3088
# DeviceProtection  7043      3                No  3095
# TechSupport       7043      3                No  3473
# StreamingTV       7043      3                No  2810
# StreamingMovies   7043      3                No  2785
# Contract          7043      3    Month-to-month  3875
# PaperlessBilling  7043      2               Yes  4171
# PaymentMethod     7043      4  Electronic check  2365
# ...

# %%
data["TotalCharges"].fillna(data["TotalCharges"].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.countplot(data["Contract"])
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for col in data.select_dtypes("object"):
    data[col]=le.fit_transform(data[col])

# %%
data
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
data.drop("customerID",axis=1,inplace=True)

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %% [markdown]
# # Feature Selection

# %%
data.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.006739       0.146185  0.142410   -0.024991  0.343032
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#we are having multicollinearity issues
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF

# %%
x=data.drop("Churn",axis=1)

# %%
vif_data=pd.DataFrame()
vif_data["features"]=x.columns
vif_data["vif"]=[VIF(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#             features        vif
# 0             gender   1.953947
# 1      SeniorCitizen   1.369493
# 2            Partner   2.821379
# 3         Dependents   1.963036
# 4             tenure  14.607408
# 5       PhoneService  15.133708
# 6      MultipleLines   2.753061
# 7    InternetService   4.352197
# 8     OnlineSecurity   2.249601
# 9       OnlineBackup   2.457285
# 10  DeviceProtection   2.632744
# 11       TechSupport   2.383049
# 12       StreamingTV   3.240746
# 13   StreamingMovies   3.261880
# 14          Contract   4.158027
# 15  PaperlessBilling   2.871391
# 16     PaymentMethod   3.093961
# 17    MonthlyCharges  20.402779
# 18      TotalCharges  13.644663

# %%
data.drop("MonthlyCharges",axis=1,inplace=True)

# %%
x=data.drop("Churn",axis=1)
vif_data=pd.DataFrame()
vif_data["features"]=x.columns
vif_data["vif"]=[VIF(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#             features        vif
# 0             gender   1.937154
# 1      SeniorCitizen   1.342949
# 2            Partner   2.816399
# 3         Dependents   1.962937
# 4             tenure  13.541648
# 5       PhoneService   8.197111
# 6      MultipleLines   2.509612
# 7    InternetService   3.638673
# 8     OnlineSecurity   2.249193
# 9       OnlineBackup   2.455879
# 10  DeviceProtection   2.620412
# 11       TechSupport   2.382669
# 12       StreamingTV   3.096812
# 13   StreamingMovies   3.113408
# 14          Contract   4.027480
# 15  PaperlessBilling   2.611300
# 16     PaymentMethod   3.022955
# 17      TotalCharges   9.875628

# %%
data.drop("tenure",axis=1,inplace=True)

# %%
x=data.drop("Churn",axis=1)
vif_data=pd.DataFrame()
vif_data["features"]=x.columns
vif_data["vif"]=[VIF(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#             features       vif
# 0             gender  1.920395
# 1      SeniorCitizen  1.341120
# 2            Partner  2.753165
# 3         Dependents  1.962143
# 4       PhoneService  8.196014
# 5      MultipleLines  2.497977
# 6    InternetService  3.488519
# 7     OnlineSecurity  2.230603
# 8       OnlineBackup  2.443909
# 9   DeviceProtection  2.620156
# 10       TechSupport  2.382047
# 11       StreamingTV  3.075687
# 12   StreamingMovies  3.098635
# 13          Contract  3.022182
# 14  PaperlessBilling  2.601853
# 15     PaymentMethod  3.022587
# 16      TotalCharges  5.310505

# %%
data.drop("PhoneService",axis=1,inplace=True)

# %%
x=data.drop("Churn",axis=1)
vif_data=pd.DataFrame()
vif_data["features"]=x.columns
vif_data["vif"]=[VIF(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#             features       vif
# 0             gender  1.865085
# 1      SeniorCitizen  1.336639
# 2            Partner  2.743350
# 3         Dependents  1.955587
# 4      MultipleLines  2.490523
# 5    InternetService  2.528751
# 6     OnlineSecurity  2.198201
# 7       OnlineBackup  2.439487
# 8   DeviceProtection  2.618942
# 9        TechSupport  2.359665
# 10       StreamingTV  3.075670
# 11   StreamingMovies  3.098571
# 12          Contract  3.005043
# 13  PaperlessBilling  2.408254
# 14     PaymentMethod  2.616692
# 15      TotalCharges  5.069936

# %%
data.drop("TotalCharges",axis=1,inplace=True)

# %%
x=data.drop("Churn",axis=1)
vif_data=pd.DataFrame()
vif_data["features"]=x.columns
vif_data["vif"]=[VIF(x.values,i) for i in range(len(x.columns))]
vif_data
# Out:
#             features       vif
# 0             gender  1.864775
# 1      SeniorCitizen  1.324879
# 2            Partner  2.666241
# 3         Dependents  1.939944
# 4      MultipleLines  2.174448
# 5    InternetService  2.329328
# 6     OnlineSecurity  2.161023
# 7       OnlineBackup  2.279408
# 8   DeviceProtection  2.540886
# 9        TechSupport  2.350746
# 10       StreamingTV  2.957034
# 11   StreamingMovies  2.979966
# 12          Contract  2.829601
# 13  PaperlessBilling  2.347401
# 14     PaymentMethod  2.499831

# %% [markdown]
# # model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  MultipleLines  \
# 0          0              0        1           0              1
# 1          1              0        0           0              0
# 2          1              0        0           0              0
# 3          1              0        0           0              1
# 4          0              0        0           0              0
# ...      ...            ...      ...         ...            ...
# 7038       1              0        1           1              2
# 7039       0              0        1           1              2
# 7040       0              0        1           1              1
# 7041       1              1        1           0              2
# 7042       1              0        0           0              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 0                   0               0             2                 0
# ...

# %%
x=data.drop("Churn",axis=1)
y=data["Churn"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=43)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import *
accuracy_score(y_test,y_pred)
# Out:
# 0.7773992049971608

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[1166,  131],
#        [ 261,  203]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1297
#            1       0.61      0.44      0.51       464
#
#     accuracy                           0.78      1761
#    macro avg       0.71      0.67      0.68      1761
# weighted avg       0.76      0.78      0.76      1761
