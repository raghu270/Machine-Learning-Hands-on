# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("C:\\Users\\raghu\\Downloads\\nba_final.csv")

# %%
data
# Out:
#        Rk         Player.x  Player_ID Pos1 Pos2  Age   Tm   G  GS    MP  ...  \
# 0     170     A.J. Hammons  hammoaj01    C  NaN   24  DAL  22   0   7.4  ...
# 1      58     Aaron Brooks  brookaa01   PG  NaN   32  IND  65   0  13.8  ...
# 2     157     Aaron Gordon  gordoaa01   SF  NaN   21  ORL  80  72  28.7  ...
# 3     352    Adreian Payne  paynead01   PF  NaN   25  MIN  18   0   7.5  ...
# 4      10  Al-Farouq Aminu  aminual01   PF  NaN   26  POR  61  25  29.1  ...
# ...   ...              ...        ...  ...  ...  ...  ...  ..  ..   ...  ...
# 1403  109     Zach Collins  colliza01    C  NaN   21  POR  77   0  17.6  ...
# 1404  294      Zach LaVine  lavinza01   SG  NaN   23  CHI  63  62  34.5  ...
# 1405  308      Zach Lofton  loftoza01   SG  NaN   26  DET   1   0   4.0  ...
# 1406  393    Zaza Pachulia  pachuza01    C  NaN   34  DET  68   3  12.9  ...
# 1407  457     Zhaire Smith  smithzh01   SG  NaN   19  PHI   6   2  18.5  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 45 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          1408 non-null   int64
#  1   Player.x    1408 non-null   object
#  2   Player_ID   1408 non-null   object
#  3   Pos1        1408 non-null   object
#  4   Pos2        12 non-null     object
#  5   Age         1408 non-null   int64
#  6   Tm          1408 non-null   object
#  7   G           1408 non-null   int64
#  8   GS          1408 non-null   int64
#  9   MP          1408 non-null   float64
#  10  FG          1408 non-null   float64
#  11  FGA         1408 non-null   float64
#  12  FG.         1404 non-null   float64
#  13  X3P         1408 non-null   float64
#  14  X3PA        1408 non-null   float64
#  15  X3P.        1309 non-null   float64
#  16  X2P         1408 non-null   float64
#  17  X2PA        1408 non-null   float64
#  18  X2P.        1393 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Rk               0
# Player.x         0
# Player_ID        0
# Pos1             0
# Pos2          1396
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG.              4
# X3P              0
# X3PA             0
# X3P.            99
# X2P              0
# X2PA             0
# X2P.            15
# eFG.             4
# FT               0
# FTA              0
# FT.             47
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Salary          62
# mean_views     138
# Season           0
# Conference       0
# Role             0
# Fvot             0
# FRank            0
# Pvot           159
# PRank          159
# Mvot           404
# MRank          404
# Score            0
# Play             0
# dtype: int64

# %%
data["Pos2"].replace(np.nan,"None",inplace=True)

# %%
data.fillna(0,inplace=True)

# %%
data.drop(columns=['Player.x','Player_ID'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for column in data.select_dtypes("object"):
    data[column]=le.fit_transform(data[column])

# %%
X=data.drop("Play",axis=1)
y=data["Play"]

# %%
from sklearn.preprocessing import StandardScaler #scaling is required when you are dealing with LDA

# %%
scaler=StandardScaler()

# %%
X=scaler.fit_transform(X)
X
# Out:
# array([[-0.58191469, -1.40108842, -0.07184075, ..., -0.16623906,
#         -1.46817686,  0.19138945],
#        [-1.32505241, -0.01428174, -0.07184075, ..., -0.16623906,
#         -1.46817686, -0.66146791],
#        [-0.66817174,  0.67912159, -0.07184075, ..., -0.16623906,
#         -1.46817686, -0.85958209],
#        ...,
#        [ 0.33373715,  1.37252493, -0.07184075, ..., -0.16623906,
#          0.83574403,  1.36799438],
#        [ 0.8977256 , -1.40108842, -0.07184075, ..., -0.16623906,
#          0.54775392, -0.13960618],
#        [ 1.32237572,  1.37252493, -0.07184075, ..., -0.16623906,
#          0.83574403,  1.09256735]])

# %%
d=data.drop('Play',axis=1)
col=list(d.columns)

# %%
X=pd.DataFrame(X,columns=col)

# %%
X
# Out:
#             Rk      Pos1      Pos2       Age        Tm         G        GS  \
# 0    -0.581915 -1.401088 -0.071841 -0.499694 -0.978040 -1.335031 -0.904118
# 1    -1.325052 -0.014282 -0.071841  1.369015 -0.397581  0.453360 -0.904118
# 2    -0.668172  0.679122 -0.071841 -1.200460  0.763336  1.077217  1.608585
# 3     0.625684 -0.707685 -0.071841 -0.266105  0.298969 -1.501393 -0.904118
# 4    -1.643540 -0.707685 -0.071841 -0.032517  1.111611  0.286998 -0.031652
# ...        ...       ...       ...       ...       ...       ...       ...
# 1403 -0.986659 -1.401088 -0.071841 -1.200460  1.111611  0.952446 -0.904118
# 1404  0.240845  1.372525 -0.071841 -0.733283 -1.326315  0.370179  1.259599
# 1405  0.333737  1.372525 -0.071841 -0.032517 -0.745856 -2.208431 -0.904118
# 1406  0.897726 -1.401088 -0.071841  1.836193 -0.745856  0.578131 -0.799422
# 1407  1.322376  1.372525 -0.071841 -1.667637  0.879428 -2.000478 -0.834321
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9822695035460993

# %% [markdown]
# # LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
X
# Out:
#             Rk      Pos1      Pos2       Age        Tm         G        GS  \
# 0    -0.581915 -1.401088 -0.071841 -0.499694 -0.978040 -1.335031 -0.904118
# 1    -1.325052 -0.014282 -0.071841  1.369015 -0.397581  0.453360 -0.904118
# 2    -0.668172  0.679122 -0.071841 -1.200460  0.763336  1.077217  1.608585
# 3     0.625684 -0.707685 -0.071841 -0.266105  0.298969 -1.501393 -0.904118
# 4    -1.643540 -0.707685 -0.071841 -0.032517  1.111611  0.286998 -0.031652
# ...        ...       ...       ...       ...       ...       ...       ...
# 1403 -0.986659 -1.401088 -0.071841 -1.200460  1.111611  0.952446 -0.904118
# 1404  0.240845  1.372525 -0.071841 -0.733283 -1.326315  0.370179  1.259599
# 1405  0.333737  1.372525 -0.071841 -0.032517 -0.745856 -2.208431 -0.904118
# 1406  0.897726 -1.401088 -0.071841  1.836193 -0.745856  0.578131 -0.799422
# 1407  1.322376  1.372525 -0.071841 -1.667637  0.879428 -2.000478 -0.834321
#
# ...

# %%
lda = LinearDiscriminantAnalysis()

# %%
X=lda.fit_transform(X,y)

# %%
X
# Out:
# array([[-1.03229414],
#        [-0.50134906],
#        [-0.57346384],
#        ...,
#        [-0.72836767],
#        [-0.37294989],
#        [-0.8653202 ]])

# %%
X.shape
# Out:
# (1408, 1)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1403    0
# 1404    0
# 1405    0
# 1406    0
# 1407    0
# Name: Play, Length: 1408, dtype: int32

# %%
# no of columns that are created ->min(n_classes-1,no_features) classes->output column

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
model1=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9858156028368794
